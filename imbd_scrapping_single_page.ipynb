# %%
from requests import get

# %%
from requests import get

url = 'http://www.imdb.com/search/title?release_date=2017&sort=num_votes,desc&page=1'

response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle"

# %%
from bs4 import BeautifulSoup

html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
movie_containers = html_soup.find_all('div', class_ = 'lister-item mode-advanced')
print(type(movie_containers))
print(len(movie_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 50

# %%
# Lists to store the scraped data in
names = []
years = []
imdb_ratings = []
metascores = []
votes = []

# Extract data from individual movie container
for container in movie_containers:

    # If the movie has Metascore, then extract:
    if container.find('div', class_ = 'ratings-metascore') is not None:

        # The name
        name = container.h3.a.text
        names.append(name)

        # The year
        year = container.h3.find('span', class_ = 'lister-item-year').text
        years.append(year)

        # The IMDB rating
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)

        # The Metascore
        m_score = container.find('span', class_ = 'metascore').text
        metascores.append(int(m_score))

        # The number of votes
        vote = container.find('span', attrs = {'name':'nv'})['data-value']
        votes.append(int(vote))

# %%
#use pandas for storing the extracted data from above
import pandas as pd

test_df = pd.DataFrame({'movie': names,
                       'year': years,
                       'imdb': imdb_ratings,
                       'metascore': metascores,
                       'votes': votes})
print(test_df.info())
test_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 5 columns):
# movie        46 non-null object
# year         46 non-null object
# imdb         46 non-null float64
# metascore    46 non-null int64
# votes        46 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.9+ KB
# None
#                                                movie        year  imdb  \
# 0                                              Logan      (2017)   8.1
# 1                                       Wonder Woman      (2017)   7.5
# 2                                            Dunkirk      (2017)   8.0
# 3            Star Wars: Episode VIII - The Last Jedi      (2017)   7.3
# 4                     Guardians of the Galaxy Vol. 2      (2017)   7.7
# 5                                     Thor: Ragnarok      (2017)   7.9
# 6                             Spider-Man: Homecoming      (2017)   7.5
# 7                                            Get Out  (I) (2017)   7.7
# 8                                  Blade Runner 2049      (2017)   8.1
# 9                                        Baby Driver      (2017)   7.7
# 10                                                It  (I) (2017)   7.4
# 11                                    Justice League      (2017)   6.6
# 12         Three Billboards Outside Ebbing, Missouri      (2017)   8.2
# 13                              John Wick: Chapter 2      (2017)   7.5
# 14                                The Shape of Water      (2017)   7.4
# 15                              Beauty and the Beast      (2017)   7.2
# 16                                Kong: Skull Island      (2017)   6.7
# 17                                   Alien: Covenant      (2017)   6.4
# 18  Pirates of the Caribbean: Dead Men Tell No Tales      (2017)   6.6
# 19                                              Coco  (I) (2017)   8.5
# 20                       Kingsman: The Golden Circle      (2017)   6.8
# 21                    Jumanji: Welcome to the Jungle      (2017)   7.0
# 22                    War for the Planet of the Apes      (2017)   7.5
# 23                           The Fate of the Furious      (2017)   6.7
# 24                                              Life  (I) (2017)   6.6
# 25                                Ghost in the Shell      (2017)   6.4
# 26                  King Arthur: Legend of the Sword      (2017)   6.8
# 27                      Murder on the Orient Express      (2017)   6.5
# 28                              The Greatest Showman      (2017)   7.7
# 29                            The Hitman's Bodyguard      (2017)   6.9
# 30                                         The Mummy      (2017)   5.5
# 31                                         Lady Bird      (2017)   7.5
# 32                                        Wind River      (2017)   7.8
# 33                                            Bright  (I) (2017)   6.4
# 34                                     Atomic Blonde      (2017)   6.7
# 35                                           Mother!      (2017)   6.7
# 36       Valerian and the City of a Thousand Planets      (2017)   6.5
# 37                              Call Me by Your Name      (2017)   8.0
# 38                                          Baywatch      (2017)   5.6
# 39                                     American Made      (2017)   7.2
# 40                                      Darkest Hour      (2017)   7.4
# 41                             The Lego Batman Movie      (2017)   7.3
# 42                     Transformers: The Last Knight      (2017)   5.2
# 43                                          I, Tonya      (2017)   7.5
# 44                                    The Dark Tower      (2017)   5.7
# 45                                      The Big Sick      (2017)   7.6
#
#     metascore   votes
# 0          77  491100
# 1          76  420932
# 2          94  400302
# 3          85  395157
# 4          67  391388
# 5          74  353810
# 6          73  337371
# 7          84  314655
# 8          81  308327
# 9          86  307168
# 10         69  284388
# 11         45  261527
# 12         88  250552
# 13         75  233782
# 14         87  227777
# 15         65  209977
# 16         62  209323
# 17         65  202644
# 18         39  199038
# 19         81  191935
# 20         44  186429
# 21         58  177791
# 22         82  176492
# 23         56  162943
# 24         54  159826
# 25         52  155185
# 26         41  150826
# 27         52  142819
# 28         48  136273
# 29         47  135875
# 30         34  135314
# 31         94  132170
# 32         73  130019
# 33         29  129476
# 34         63  127497
# 35         75  123152
# 36         51  120247
# 37         93  113141
# 38         37  109107
# 39         65  104803
# 40         75  103423
# 41         75  101470
# 42         27  101436
# 43         77   97330
# 44         34   92456
# 45         86   88519
